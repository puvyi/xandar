# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %%
life = pd.read_csv('data/gapminder_total_fertility.csv', index_col=0)

# %%
fert = pd.read_excel('data/gapminder_lifeexpectancy.xlsx', index_col=0)

# %%
fert[[1950,1975,2000,2015]]
# Out:
#                         1950   1975  2000  2015
# Life expectancy
# Abkhazia                 NaN    NaN   NaN   NaN
# Afghanistan            26.85  39.61  50.1  53.8
# Akrotiri and Dhekelia    NaN    NaN   NaN   NaN
# Albania                54.48  69.77  74.7  78.0
# Algeria                42.77  55.24  73.3  76.4
# ...                      ...    ...   ...   ...
# Yugoslavia               NaN    NaN   NaN   NaN
# Zambia                 42.85  56.70  44.8  56.7
# Zimbabwe               48.46  59.41  47.9  59.3
# Åland                    NaN    NaN  80.0   NaN
# South Sudan            28.14  42.93  54.4  56.1
#
# [260 rows x 4 columns]

# %%
lifexp = pd.read_excel('data/gapminder_lifeexpectancy.xlsx', index_col=0)

# %%
lifexp.head()
# Out:
#                         1800   1801   1802   1803   1804   1805   1806   1807  \
# Life expectancy
# Abkhazia                 NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# Afghanistan            28.21  28.20  28.19  28.18  28.17  28.16  28.15  28.14
# Akrotiri and Dhekelia    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# Albania                35.40  35.40  35.40  35.40  35.40  35.40  35.40  35.40
# Algeria                28.82  28.82  28.82  28.82  28.82  28.82  28.82  28.82
#
#                         1808   1809  ...  2007  2008  2009  2010  2011  2012  \
# Life expectancy                      ...
# Abkhazia                 NaN    NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN
# Afghanistan            28.13  28.12  ...  52.4  52.8  53.3  53.6  54.0  54.4
# Akrotiri and Dhekelia    NaN    NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN
# Albania                35.40  35.40  ...  76.6  76.8  77.0  77.2  77.4  77.5
# ...

# %%
life_expect=lifexp[[1950,1975,2000,2015]]

# %%
life_expect[2015].hist(bins=50)
# Out:
# <Axes: >

# %%
plt.title("Hey goodiee")
plt.xlabel('')
life_expect[2015].hist(bins=25)
plt.savefig('histo.png')
#plt.axis([0.0, 50.0, 0.0, 10.0])

# %%
sns.histplot(data=life_expect[1950], bins = 50)
# Out:
# /home/puviy/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/puviy/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='1950', ylabel='Count'>

# %%
fert.tail()
# Out:
#                   1800   1801   1802   1803   1804   1805   1806   1807  \
# Life expectancy
# Yugoslavia         NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# Zambia           32.60  32.60  32.60  32.60  32.60  32.60  32.60  32.60
# Zimbabwe         33.70  33.70  33.70  33.70  33.70  33.70  33.70  33.70
# Åland              NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# South Sudan      26.67  26.67  26.67  26.67  26.67  26.67  26.67  26.67
#
#                   1808   1809  ...  2007  2008  2009  2010  2011  2012  2013  \
# Life expectancy                ...
# Yugoslavia         NaN    NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Zambia           32.60  32.60  ...  49.0  51.1  52.3  53.1  53.7  54.7  55.6
# Zimbabwe         33.70  33.70  ...  46.4  47.3  48.0  49.1  51.6  54.2  55.7
# Åland              NaN    NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# South Sudan      26.67  26.67  ...  55.5  55.6  55.8  56.0  55.9  56.0  56.0
#
# ...

# %%
life.shape, fert.shape
# Out:
# ((260, 216), (260, 217))

# %%
fert.dtypes.value_counts()
# Out:
# float64    217
# Name: count, dtype: int64
